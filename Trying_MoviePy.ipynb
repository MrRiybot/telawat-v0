# %%
from moviepy.editor import *
from pytube import YouTube

# %%
# !pip install pytube
# Out:
# ...
#      ---------------------------------------- 57.2/57.2 kB 2.9 MB/s eta 0:00:00
# ...

# %%
def Download(link):
    youtubeObject = YouTube(link)
    youtubeObject = youtubeObject.streams.get_highest_resolution()
    try:
        youtubeObject.download()
    except:
        print("An error has occurred")
    print("Download is completed successfully")

# %%
Download('https://www.youtube.com/watch?v=U0f3sx4L-ko')
# Out:
# Download is completed successfully

# %%
clip = VideoFileClip("m.mp4")

# %%
value = clip.size

# %%
value
# Out:
# [1280, 676]

# %%
def ratio(clip, width=9, height=16):
    size = clip.size
    total_size = size[0] + size[1]
    print(total_size)
    return clip.crop(x1=0,y1=0, width=(total_size * width)/(width+height), height=(total_size* height)/(width+height) )

# %%
clip = ratio(clip)
# Out:
# 1956

# %%
clip.ipython_display(t=20)
# Out:
# <div align=middle><img  src='data:image/png;base64,...'></div>
